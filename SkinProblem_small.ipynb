# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics --upgrade
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 19.6 MB/s eta 0:00:00
# ...

# %%
# !cp -r /content/drive/MyDrive/SkinProblem /content/

# %%
# !cp -r /content/drive/MyDrive/YoloSeg_Results /content/

# %%
# !ls /content/drive/MyDrive/SkinProblem/
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
data_path = "/content/drive/MyDrive/SkinProblem/data.yaml"

# %%
import os
data_path = "/content/SkinProblem"
img_dir_train = os.path.join(data_path,"train","images")
img_dir_valid = os.path.join(data_path,"valid","images")
lbl_dir_train = os.path.join(data_path,"train","labels")
lbl_dir_valid = os.path.join(data_path,"valid","labels")

# %%
print("No of images/labels : ",len(os.listdir(img_dir_train)),"/",len(os.listdir(lbl_dir_train)))
print("No of images/labels : ",len(os.listdir(img_dir_valid)),"/",len(os.listdir(lbl_dir_valid)))
# Out:
# No of images/labels :  5067 / 5067
# No of images/labels :  449 / 449

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolov8s-seg.pt")

# %%
results = model.train(
    data="/content/drive/MyDrive/SkinProblem/data.yaml",  # dataset config
    epochs=50,                # longer = better convergence
    imgsz=640,                 # standard for segmentation
    batch=16,                  # you can go up to 32 if GPU memory > 16GB
    workers=4,                 # parallel data loading
    optimizer="AdamW",         # stable and modern optimizer
    lr0=0.001,                 # good starting LR for AdamW
    lrf=0.01,                  # final LR fraction (for cosine scheduler)
    cos_lr=True,               # smooth cosine learning rate decay
    momentum=0.937,            # default, keep as is
    weight_decay=0.0005,       # regularization
    dropout=0.2,               # improves generalization
    mosaic=1.0,                # mix images for robustness
    mixup=0.2,                 # mixup augmentation for variety
    cache=True,                # cache dataset in RAM for speed
    pretrained=True,           # use pretrained backbone
    device=0,                  # use GPU
    verbose=True,
    patience = 20,
    name="skin-seg-optimized",
    project="/content/drive/MyDrive/runs"
)
# Out:
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !cp /content/drive/MyDrive/runs/skin-seg8/weights/best.pt /content/drive/MyDrive/SkinProblem/
# !cp /content/drive/MyDrive/runs/skin-seg8/weights/last.pt /content/drive/MyDrive/SkinProblem/

# %%
# Load your saved model
model = YOLO("/content/drive/MyDrive/YoloSeg_Results/bestm100.pt")

# %%
# Run validation on VALID split
model.val(data="/content/drive/MyDrive/SkinProblem/data.yaml", split="val", plots = True)
# Out:
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# val: Fast image access ✅ (ping: 1.1±0.4 ms, read: 8.0±2.0 MB/s, size: 44.7 KB)
# val: Scanning /content/drive/MyDrive/SkinProblem/valid/labels.cache... 449 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 449/449 365.0Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 29/29 0.0it/s 17:43
#                    all        449       3018       0.67      0.594      0.616      0.311      0.628      0.551      0.552      0.227
#                   acne        141       1277      0.564       0.41      0.445      0.174       0.57      0.404      0.446      0.172
#            dark circle        123        211      0.792      0.848      0.849      0.459      0.786      0.836      0.825      0.382
# ...

# %%
# Run validation on TEST split
model.val(data="/content/drive/MyDrive/SkinProblem/data.yaml", split="test", plots=True)
# Out:
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# val: Fast image access ✅ (ping: 0.8±0.4 ms, read: 10.2±8.5 MB/s, size: 54.1 KB)
# val: Scanning /content/drive/MyDrive/SkinProblem/test/labels.cache... 115 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 115/115 138.8Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 0.0it/s 5:02
#                    all        115        764      0.743      0.565      0.642      0.286      0.714      0.548      0.609      0.222
#                   acne         37        369      0.634      0.357      0.445      0.177      0.607      0.344      0.436      0.166
#            dark circle         31         59      0.893      0.814      0.877      0.348      0.912      0.831      0.895      0.342
# ...

# %%
results = model.predict(
    source="/content/drive/MyDrive/SkinProblem/test/images",
    imgsz=1024,        # bigger for small lesions
    conf=0.20,         # try lower conf to increase recall, tune later
    save=True,         # saves visuals
    save_txt=False
)
# Out:
# WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
# WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
# WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
# WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
# WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
# WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
# WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
# WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
# WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
# WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
# WARNING ⚠️ Model does not support 'augment=True', reverting to single-scale prediction.
# ...

# %%
# !cp -r runs/segment/val /content/drive/MyDrive/runs/skinseg50s

# %%
# !zip -r predict_results.zip runs/segment/predict
# Out:
#   adding: runs/segment/predict/ (stored 0%)
#   adding: runs/segment/predict/05991_png_jpg.rf.b44cf40f5e9b496ed43a3fd8384b66d9.jpg (deflated 3%)
#   adding: runs/segment/predict/250_jpg.rf.b1bc9df69ade35c4adb6744a7c86f443.jpg (deflated 3%)
#   adding: runs/segment/predict/40279_2013_22_Fig4_HTML_jpg.rf.8911b4247579b1fb5b1c56edda741e60.jpg (deflated 2%)
#   adding: runs/segment/predict/2706940948_1_jpg.rf.2318fe6b3b8dd459444185653329c5e0.jpg (deflated 5%)
#   adding: runs/segment/predict/15_jpeg.rf.51cb25594ca67bc63df37f2574eed171.jpg (deflated 5%)
#   adding: runs/segment/predict/19725_png_jpg.rf.c5c1b5afc7e4a45cf596c7ff11c86754.jpg (deflated 3%)
#   adding: runs/segment/predict/15459_png_jpg.rf.05efcd2e7c5e8bbfdb506bde6b81868a.jpg (deflated 2%)
#   adding: runs/segment/predict/68_jpg.rf.cc5702a10b8eae6f62f2a298a8865a88.jpg (deflated 3%)
#   adding: runs/segment/predict/226_jpg.rf.e946e460a95b1be3b9cb5476d336d52f.jpg (deflated 2%)
# ...

# %%
from google.colab import files
files.download("predict_results.zip")

# %%
model.export(format="tflite")  # Exports to TensorFlow Lite
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
#
# PyTorch: starting from '/content/drive/MyDrive/YoloSeg_Results/bests50.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) ((1, 39, 8400), (1, 32, 160, 160)) (22.8 MB)
# requirements: Ultralytics requirements ['sng4onnx>=1.0.1', 'onnx_graphsurgeon>=0.3.26', 'ai-edge-litert>=1.2.0', 'onnx>=1.12.0', 'onnx2tf>=1.26.3', 'onnxslim>=0.1.67', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
#
# requirements: AutoUpdate success ✅ 12.0s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# TensorFlow SavedModel: starting export with tensorflow 2.19.0...
# ...
